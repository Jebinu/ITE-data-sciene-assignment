# %% [markdown]
# # recommend_exhibitors_by_answers

# %%
visitors_answers = pd.read_csv("visitors_answers.csv")

exhibitor_final=pd.read_csv("exhibitor_final.csv")

# %%
visitors_answers.head(2)
# Out:
#                          id                         answer  \
# 0  5c8a78336d41a10da4f73103              Personal interest
# 1  5c8a78336d41a10da4f73100  To obtain general information
#
#                  questionId
# 0  5c8a78336d41a10da4f730fe
# 1  5c8a78336d41a10da4f730fe

# %%
exhibitor_final.head(2)
# Out:
#    exhibitorid            Name  categoryId               categoryName
# 0        90556  Turkey Travels       52276           1.5 Resort hotel
# 1        90556  Turkey Travels       52280  2.1 Inbound tour operator

# %%
# Extract unique category names
category_texts = exhibitor_final['categoryName'].dropna().unique()

# Extract unique visitor answers
answer_texts = visitors_answers['answer'].dropna().unique()

# %%
# Clean up and deduplicate category names
category_set = set()
for cat_string in category_texts:
    for cat in str(cat_string).split(','):
        category_set.add(cat.strip().lower())

category_list = list(category_set)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Lowercase and clean answer texts
answer_list = [str(ans).strip().lower() for ans in answer_texts]

# Combine all text for fitting vectorizer
all_text = answer_list + category_list

# TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_text)

# Split TF-IDF into answers and categories
answer_vecs = tfidf_matrix[:len(answer_list)]
category_vecs = tfidf_matrix[len(answer_list):]

# Cosine similarity
similarity_matrix = cosine_similarity(answer_vecs, category_vecs)

# %%
# For each answer, get top matching category
top_matches = []
for i, ans in enumerate(answer_list):
    sims = similarity_matrix[i]
    best_idx = sims.argmax()
    top_category = category_list[best_idx]
    top_score = sims[best_idx]
    top_matches.append({'Answer': ans, 'Matched_Category': top_category, 'Score': round(top_score, 4)})

mapping_df = pd.DataFrame(top_matches)

# %%
mapping_df
# Out:
#                                             Answer  \
# 0                                personal interest
# 1                    to obtain general information
# 2                  to source products and services
# 3                 to promote products and services
# 4                             educational purposes
# 5                    formation of tourist products
# 6                             guided tour services
# 7                                 event management
# 8                                        marketing
# 9                                     visa support
# 10                              general management
# 11                                           sales
# 12                                      government
# 13                                           media
# 14                                     it services
# 15                          accommodation provider
# 16  sightseeing / museum / excursions & activities
# 17                                           other
# 18                         educational institution
# 19                                       insurance
# 20                                        glamping
# 21                           glamping manufacturer
# 22                                   tour operator
# 23               transport services / air carriage
# 24                it solutions for travel industry
# 25                           medical centre/clinic
# 26                                      caravaning
# 27                                    travel agent
# 28      management / tourism promotion & marketing
# 29             hotel equipment & services supplier
# 30                            joint responsibility
# 31                             sole responsibility
# 32                                   advisory role
# 33                                    no influence
# 34                          10 - 20 million rubles
# 35                     more than 50 million rubles
# 36                          up to 1 million rubles
# 37                           5 - 10 million rubles
# 38                            1 - 5 million rubles
# 39                                    i don't know
# 40                          20 - 50 million rubles
#
#                                      Matched_Category   Score
# 0                               5.4 transfer services  0.0000
# 1                 12.1 tic: travel information centre  0.2388
# 2   8.6 medical products and machinery manufacture...  0.3112
# 3   8.6 medical products and machinery manufacture...  0.3112
# 4                               5.4 transfer services  0.0000
# 5                12. tourist board / government / nto  0.2377
# 6                       2.6 specialized tour operator  0.2727
# 7                       11. mice and event management  0.6375
# 8                               5.4 transfer services  0.0000
# 9                               5.4 transfer services  0.0000
# 10                             1.6 management company  0.4371
# 11                              5.4 transfer services  0.0000
# 12               12. tourist board / government / nto  0.4514
# 13                                  15.2 online media  0.5774
# 14               13. it solutions for travel industry  0.3501
# 15                      17.2 payment service provider  0.3547
# 16                                        10.1 museum  0.3762
# 17                       5.6 other transport services  0.5495
# 18                              5.4 transfer services  0.0000
# 19                             17.1 insurance company  0.5869
# 20            7.3 other type of motorhomes & glamping  0.4859
# 21            7.3 other type of motorhomes & glamping  0.3523
# 22                      2.6 specialized tour operator  0.7593
# 23                       5.6 other transport services  0.5167
# 24               13. it solutions for travel industry  0.9260
# 25                        8. health & medical tourism  0.2937
# 26                              5.4 transfer services  0.0000
# 27                                3. travel  agencies  0.3166
# 28                             1.6 management company  0.3114
# 29             9. hotel equipment & service suppliers  0.4597
# 30                              5.4 transfer services  0.0000
# 31                              5.4 transfer services  0.0000
# 32                              5.4 transfer services  0.0000
# 33                              5.4 transfer services  0.0000
# 34                                        10.1 museum  0.2623
# 35                              5.4 transfer services  0.0000
# 36                              5.4 transfer services  0.0000
# 37                                        10.1 museum  0.3237
# 38                              5.4 transfer services  0.0000
# 39                              5.4 transfer services  0.0000
# 40                              5.4 transfer services  0.0000

# %%
mapping_df.to_csv('mapping_answers_to_categories.csv', index=False)
